# %%
import numpy as np
import pandas as pd
import nltk
import matplotlib.pyplot as plt
from collections import Counter
import os
os.chdir("C:/Digital Nest/NLP")

# %%
MR = pd.read_csv("MovieReviews.tsv",sep='\t')
print(MR.shape)
print(MR.columns.values)
print(MR.head())
# Out:
# (156060, 4)
# ['PhraseId' 'SentenceId' 'Phrase' 'Sentiment']
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %%
Counter(MR.Sentiment)
# Out:
# Counter({1: 27273, 2: 79582, 3: 32927, 4: 9206, 0: 7072})

# %%
len(Counter(MR.SentenceId))
# Out:
# 8529

# %%
len(Counter(MR.PhraseId))
# Out:
# 156060

# %%
MR[MR.SentenceId==1]
# Out:
#     PhraseId  SentenceId                                             Phrase  \
# 0          1           1  A series of escapades demonstrating the adage ...
# 1          2           1  A series of escapades demonstrating the adage ...
# 2          3           1                                           A series
# 3          4           1                                                  A
# 4          5           1                                             series
# 5          6           1  of escapades demonstrating the adage that what...
# 6          7           1                                                 of
# 7          8           1  escapades demonstrating the adage that what is...
# 8          9           1                                          escapades
# 9         10           1  demonstrating the adage that what is good for ...
# 10        11           1                            demonstrating the adage
# 11        12           1                                      demonstrating
# 12        13           1                                          the adage
# 13        14           1                                                the
# 14        15           1                                              adage
# 15        16           1                    that what is good for the goose
# 16        17           1                                               that
# 17        18           1                         what is good for the goose
# 18        19           1                                               what
# 19        20           1                              is good for the goose
# 20        21           1                                                 is
# 21        22           1                                 good for the goose
# 22        23           1                                               good
# 23        24           1                                      for the goose
# 24        25           1                                                for
# 25        26           1                                          the goose
# 26        27           1                                              goose
# 27        28           1  is also good for the gander , some of which oc...
# 28        29           1  is also good for the gander , some of which oc...
# 29        30           1                                            is also
# ..       ...         ...                                                ...
# 33        34           1  the gander , some of which occasionally amuses...
# 34        35           1                                       the gander ,
# 35        36           1                                         the gander
# 36        37           1                                             gander
# 37        38           1                                                  ,
# 38        39           1  some of which occasionally amuses but none of ...
# 39        40           1                                      some of which
# 40        41           1                                               some
# 41        42           1                                           of which
# 42        43           1                                              which
# 43        44           1  occasionally amuses but none of which amounts ...
# 44        45           1                                       occasionally
# 45        46           1  amuses but none of which amounts to much of a ...
# 46        47           1                                             amuses
# 47        48           1       but none of which amounts to much of a story
# 48        49           1                                                but
# 49        50           1           none of which amounts to much of a story
# 50        51           1                                               none
# 51        52           1                of which amounts to much of a story
# 52        53           1                   which amounts to much of a story
# 53        54           1                         amounts to much of a story
# 54        55           1                                            amounts
# 55        56           1                                 to much of a story
# 56        57           1                                                 to
# 57        58           1                                    much of a story
# 58        59           1                                               much
# 59        60           1                                         of a story
# 60        61           1                                            a story
# 61        62           1                                              story
# 62        63           1                                                  .
#
#     Sentiment
# 0           1
# 1           2
# 2           2
# 3           2
# 4           2
# 5           2
# 6           2
# 7           2
# 8           2
# 9           2
# 10          2
# 11          2
# 12          2
# 13          2
# 14          2
# 15          2
# 16          2
# 17          2
# 18          2
# 19          2
# 20          2
# 21          3
# 22          3
# 23          2
# 24          2
# 25          2
# 26          2
# 27          2
# 28          2
# 29          2
# ..        ...
# 33          1
# 34          2
# 35          2
# 36          2
# 37          2
# 38          2
# 39          2
# 40          2
# 41          2
# 42          2
# 43          2
# 44          2
# 45          2
# 46          3
# 47          1
# 48          2
# 49          1
# 50          2
# 51          2
# 52          2
# 53          2
# 54          2
# 55          2
# 56          2
# 57          2
# 58          2
# 59          2
# 60          2
# 61          2
# 62          2
#
# [63 rows x 4 columns]

# %%
# remove punctuation marks
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
Phrase2 = list()
for phrase in MR.Phrase:
    phrasewords = tokenizer.tokenize(phrase)
    Phrase2.append(' '.join(phrasewords))
print(len(Phrase2))
# Out:
# 156060

# %%
print(MR.Phrase[0])
print(Phrase2[0])
# Out:
# A series of escapades demonstrating the adage that what is good for the goose is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .
# A series of escapades demonstrating the adage that what is good for the goose is also good for the gander some of which occasionally amuses but none of which amounts to much of a story

# %%
# remove numbers
Phrase3 = list()
for string in Phrase2:
    translation = string.maketrans("","","0123456789")
    string = string.translate(translation)
    Phrase3.append(string)
print(len(Phrase3))
# Out:
# 156060

# %%
# convert into lowercase
Phrase4 = list()
for string in Phrase3:
    string = string.lower()
    Phrase4.append(string)
print(len(Phrase4))
# Out:
# 156060

# %%
X = pd.DataFrame({"phrase": Phrase4})
print(X.shape)
Y = pd.DataFrame(MR,columns=['Sentiment'])
print(Y.shape)
# Out:
# (156060, 1)
# (156060, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split( X, Y,
                                                   test_size = 0.2,
                                                   random_state = 0)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (124848, 1)
# (124848, 1)
# (31212, 1)
# (31212, 1)

# %%
# create TFID vector
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(lowercase = True, analyzer = 'word', stop_words = 'english',
                             max_df=100, min_df=1,max_features=500,
                             binary=True)
X_train2 = vectorizer.fit_transform(X_train.phrase)
X_test2 = vectorizer.transform(X_test.phrase)
print(X_train2.shape)
print(X_test2.shape)
print(vectorizer.get_feature_names())
# Out:
# (124848, 500)
# (31212, 500)
# ['absorbing', 'add', 'admirable', 'adolescent', 'adult', 'affair', 'affection', 'affirming', 'aged', 'ages', 'alive', 'allen', 'allows', 'americans', 'angst', 'animal', 'anne', 'annoying', 'answers', 'anti', 'apart', 'apparent', 'appears', 'artificial', 'ask', 'aspects', 'atmosphere', 'attraction', 'avoid', 'balance', 'band', 'basic', 'bears', 'beat', 'begins', 'behavior', 'believable', 'belly', 'bits', 'blade', 'blair', 'blue', 'body', 'bond', 'bore', 'bright', 'brings', 'broken', 'brought', 'brown', 'bullock', 'bunch', 'camp', 'captures', 'casting', 'cause', 'challenging', 'chance', 'changing', 'channel', 'chase', 'check', 'chemistry', 'child', 'chilling', 'chinese', 'christmas', 'cinematography', 'clarity', 'clearly', 'cliched', 'comedic', 'commentary', 'commercial', 'common', 'community', 'complete', 'complicated', 'concerned', 'condition', 'conflict', 'connect', 'conscious', 'constructed', 'conventional', 'conviction', 'courage', 'course', 'creates', 'credit', 'credits', 'cross', 'cult', 'damned', 'dance', 'decades', 'deeper', 'definitely', 'delicate', 'delight', 'delivery', 'derivative', 'desire', 'details', 'devoid', 'die', 'digital', 'dimensional', 'directing', 'directorial', 'dirty', 'discovery', 'diverting', 'document', 'doubt', 'downright', 'dreary', 'drug', 'dvd', 'early', 'earth', 'editing', 'effect', 'efforts', 'em', 'emotion', 'empathy', 'endearing', 'endless', 'energetic', 'escape', 'essentially', 'excitement', 'exciting', 'expected', 'experiences', 'exploration', 'extraordinary', 'extremely', 'eyed', 'faced', 'failure', 'faith', 'fall', 'false', 'families', 'fan', 'fantastic', 'fare', 'fat', 'fatal', 'father', 'favor', 'fear', 'fears', 'festival', 'fight', 'figure', 'filled', 'finding', 'finds', 'finish', 'fish', 'follow', 'footage', 'forced', 'foreign', 'forgettable', 'formulaic', 'frank', 'frequently', 'frustrating', 'funniest', 'games', 'gangster', 'general', 'generally', 'generation', 'generic', 'genuinely', 'giant', 'giving', 'glimpse', 'glory', 'grade', 'grand', 'graphic', 'green', 'grief', 'gripping', 'ground', 'group', 'grow', 'growing', 'guilty', 'guns', 'hackneyed', 'hair', 'hands', 'hardly', 'hate', 'heard', 'hearted', 'heartfelt', 'heaven', 'hits', 'hoffman', 'holds', 'holes', 'holiday', 'hop', 'hope', 'horrible', 'humorous', 'humour', 'husband', 'ice', 'identity', 'ill', 'image', 'imaginative', 'imax', 'including', 'incredibly', 'indian', 'indulgent', 'industry', 'inevitable', 'inner', 'insightful', 'inspiring', 'intellectual', 'intense', 'intensity', 'intentions', 'intrigue', 'involving', 'iranian', 'italian', 'jack', 'jackson', 'james', 'japanese', 'joy', 'kevin', 'king', 'kissinger', 'knowing', 'knowledge', 'lame', 'land', 'largely', 'larger', 'leads', 'leaving', 'lesson', 'lets', 'levels', 'liked', 'lines', 'lived', 'longer', 'lots', 'ludicrous', 'machine', 'main', 'mainstream', 'male', 'mark', 'marks', 'martin', 'match', 'mayhem', 'meandering', 'melodramatic', 'mention', 'mere', 'mild', 'minded', 'mindless', 'minor', 'miss', 'missed', 'missing', 'mix', 'mixed', 'modest', 'monty', 'motion', 'murphy', 'nasty', 'national', 'natural', 'near', 'needed', 'news', 'nicely', 'niro', 'noir', 'numbers', 'oddly', 'offensive', 'office', 'older', 'onscreen', 'opening', 'opportunity', 'ordinary', 'originality', 'overcome', 'overly', 'paced', 'pack', 'packed', 'painfully', 'paper', 'park', 'particular', 'performers', 'person', 'persona', 'personality', 'perspective', 'peter', 'philosophical', 'playful', 'pleasant', 'poetic', 'poetry', 'poignant', 'pointless', 'police', 'politics', 'poorly', 'possibly', 'potentially', 'powers', 'present', 'price', 'produced', 'product', 'protagonist', 'provide', 'public', 'pull', 'puts', 'question', 'quick', 'quickly', 'quietly', 'rarely', 'raw', 'realism', 'realistic', 'recommend', 'record', 'refreshing', 'relatively', 'remember', 'rendered', 'respect', 'revealing', 'reveals', 'revenge', 'revolution', 'rhythms', 'rip', 'riveting', 'routine', 'runs', 'ryan', 'sadness', 'said' ...

# %%
from sklearn.linear_model import LogisticRegression
LGR = LogisticRegression(penalty='none',solver='lbfgs')
LGR.fit(X_train2,Y_train)
print(LGR.coef_)
print(LGR.intercept_)
# Out:
# C:\Users\Vishnu Murthy Chakka\Anaconda3\lib\site-packages\sklearn\utils\validation.py
#    1.34483454e+00 -1.41943341e-01  1.90655937e+00  1.80351450e+00
#    3.35044327e-01  7.03990457e-01 -3.56806865e-02 -1.48335540e+00
#    1.49434713e-02 -8.58842334e-01 -9.99013525e-01 -1.59135054e+00
#    1.38329277e+00  1.18755794e+00 -1.58224041e+00 -1.13280497e+00
#   -1.19361897e+00  6.52018501e-01 -2.14351909e-01  2.75589594e-01
#    1.72643811e-01 -1.29248406e+00  3.66404338e-01 -5.22112933e-01
#    2.48638030e-01  8.87175853e-01  1.13157659e+00 -8.37178557e-01
#   -6.71003166e-01  1.01100907e+00  1.99474567e-01  1.74703229e-01
#    5.65369522e-01  5.00547471e-01  1.38589358e+00  1.11668597e+00
#   -2.26422864e-01  4.06071535e-01 -4.74118103e-01  8.42160682e-01
#   -3.94336794e-01  1.47023816e-01 -8.12566199e-01  2.30634593e-01
#   -3.43624648e-01 -1.30286052e+00  3.87953546e-01  2.49614782e-01
#   -1.26125640e+00  5.44775658e-01  1.69477831e+00  6.59576689e-01
#    5.28415534e-01 -1.36215906e+00 -1.48675765e+00 -1.10047956e+00
#    1.12850941e-01  9.82728830e-01  2.71939063e-01 -5.52139865e-01]]
# [-1.17041086  0.24315381  1.34866738  0.44032574 -0.86173607]
# C:\Users\Vishnu Murthy Chakka\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
LGR.score(X_train2,Y_train)
# Out:
# 0.5132801486607715

# %%
predict = LGR.predict(X_test2)
Counter(predict)
# Out:
# Counter({2: 30365, 1: 296, 3: 475, 0: 53, 4: 23})

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(Y_test,predict))
print(classification_report(Y_test,predict))
# Out:
# [[   15    59  1410    17     3]
#  [    6   115  5258    70     4]
#  [   13    77 15764   123     5]
#  [   10    37  6202   185     7]
#  [    9     8  1731    80     4]]
#               precision    recall  f1-score   support
#
#            0       0.28      0.01      0.02      1504
#            1       0.39      0.02      0.04      5453
#            2       0.52      0.99      0.68     15982
#            3       0.39      0.03      0.05      6441
#            4       0.17      0.00      0.00      1832
#
#     accuracy                           0.52     31212
#    macro avg       0.35      0.21      0.16     31212
# weighted avg       0.44      0.52      0.37     31212

# %%
from sklearn.naive_bayes import BernoulliNB
BNB = BernoulliNB()
BNB.fit(X_train2,Y_train)
print(BNB.score(X_train2,Y_train))
# Out:
# 0.5340814430347303
# C:\Users\Vishnu Murthy Chakka\Anaconda3\lib\site-packages\sklearn\utils\validation.py:744: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
predict2 = BNB.predict(X_test2)
Counter(predict2)
# Out:
# Counter({2: 28020, 3: 1756, 1: 1131, 4: 151, 0: 154})

# %%
print(confusion_matrix(Y_test,predict2))
print(classification_report(Y_test,predict2))
# Out:
# [[   59   221  1176    42     6]
#  [   59   437  4757   189    11]
#  [   26   325 15165   445    21]
#  [    9   118  5508   755    51]
#  [    1    30  1414   325    62]]
#               precision    recall  f1-score   support
#
#            0       0.38      0.04      0.07      1504
#            1       0.39      0.08      0.13      5453
#            2       0.54      0.95      0.69     15982
#            3       0.43      0.12      0.18      6441
#            4       0.41      0.03      0.06      1832
#
#     accuracy                           0.53     31212
#    macro avg       0.43      0.24      0.23     31212
# weighted avg       0.48      0.53      0.42     31212
